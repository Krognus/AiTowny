# %% [markdown]
# <a href="https://colab.research.google.com/github/Krognus/AiTowny/blob/main/Copy_of_Wget_bbsUntitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget \
  --mirror \
  --convert-links \
  --adjust-extension \
  --page-requisites \
  --no-parent \
  --limit-rate=200k \
  --domains=wiki.mysticbbs.com \
  https://wiki.mysticbbs.com/doku.php?id=start
# Out:
# Streaming output truncated to the last 5000 lines.
# Last-modified header missing -- time-stamps turned off.
# 2025-10-15 20:41:47 (152 MB/s) - ‘wiki.mysticbbs.com/doku.php?id=mutil_auto_hatch&do=backlink.html’ saved [10718]
#
# nofollow attribute found in wiki.mysticbbs.com/doku.php?id=mutil_auto_hatch&do=backlink.html. Will not follow any links on this page
# --2025-10-15 20:41:47--  https://wiki.mysticbbs.com/lib/exe/taskrunner.php?id=mutil_auto_hatch&1760560851
# Reusing existing connection to wiki.mysticbbs.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42 [image/gif]
# Saving to: ‘wiki.mysticbbs.com/lib/exe/taskrunner.php?id=mutil_auto_hatch&1760560851’
#
# wiki.mysticbbs.com/ 100%[===================>]      42  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-10-15 20:41:47 (25.5 MB/s) - ‘wiki.mysticbbs.com/lib/exe/taskrunner.php?id=mutil_auto_hatch&1760560851’ saved [42/42]
#
# ...

# %%
# !zip -r mysticbbs_wiki.zip wiki.mysticbbs.com
# Out:
# updating: wiki.mysticbbs.com/ (stored 0%)
# updating: wiki.mysticbbs.com/doku.php?id=config_newuser_settings3&do=login&sectok=.html (deflated 70%)
# updating: wiki.mysticbbs.com/doku.php?id=config_file_base_settings&do=recent.html (deflated 77%)
# updating: wiki.mysticbbs.com/doku.php?id=bbslist&do=login&sectok=.html (deflated 69%)
# updating: wiki.mysticbbs.com/doku.php?id=config_newuser_settings2&do=revisions.html (deflated 85%)
# updating: wiki.mysticbbs.com/doku.php?id=config_server_options&do=revisions.html (deflated 85%)
# updating: wiki.mysticbbs.com/doku.php?id=config_edit_new_user_notify&do=index.html (deflated 83%)
# updating: wiki.mysticbbs.com/doku.php?do=export_raw&id=config_message_base_settings (deflated 70%)
# updating: wiki.mysticbbs.com/doku.php?id=start.html (deflated 80%)
# updating: wiki.mysticbbs.com/doku.php?id=config_edit_ip_whitelist&do=revisions.html (deflated 75%)
# ...
